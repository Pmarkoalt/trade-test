# %% [markdown]
# # Portfolio Analysis
#
# This notebook demonstrates how to analyze backtest results in detail.
#
# ## Analysis Topics
#
# - Equity curve analysis
# - Trade-by-trade breakdown
# - Risk metrics
# - Performance attribution
# - Position sizing analysis
